# %%
#%pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#%matplotlib inline

# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
#For 3d plots
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.random.normal(1,.2,1000)
y = np.random.normal(2,.4,1000)

# %%
z = 1./x

# %% [markdown]
# ## With Matplotlib

# %%
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z, alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(x,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(y,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## With Seaborn

# %%
import seaborn as sns

# %%
sns.distplot(x)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
g = sns.JointGrid(x,z)
g.set_axis_labels('x','x/y')
g = g.plot_joint(plt.scatter, alpha=0.5)
g = g.plot_marginals(sns.distplot)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#with density plots
g = sns.JointGrid(x,z)
g.set_axis_labels('x','x/y')
g = g.plot_joint(sns.kdeplot, cmap="Blues_d")
g = g.plot_marginals(sns.kdeplot, shade=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#with regression curve
g = sns.JointGrid(x,z)
g.set_axis_labels('x','z')
g = g.plot(sns.regplot, sns.distplot)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.distplot(z,rug=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from scipy.stats import norm #will use this for plotting

# %%
test = norm.pdf(x,)
